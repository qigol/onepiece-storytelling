# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('character_info_v1.csv')

# %%
character_df = df.drop([df.columns[0]], axis=1)

# %%
character_df.loc[character_df.iloc[:, character_df.columns.get_loc('Affiliations')].str.contains('Pirates', na=False)].groupby('Affiliations').sum('Bounty')[['Bounty']].sort_values(by='Bounty', ascending=False)
# Out:
#                                  Bounty
# Affiliations
# Straw Hat Pirates          8.816001e+09
# Beasts Pirates             8.321100e+09
# Whitebeard Pirates         5.596000e+09
# Roger Pirates              5.564800e+09
# Big Mom Pirates            5.252500e+09
# ...                                 ...
# Blackbeard Pirates         0.000000e+00
# Red Hair Pirates (former)  0.000000e+00
# Rocks Pirates              0.000000e+00
# Rocks Pirates (former)     0.000000e+00
# A O Pirates                0.000000e+00
#
# [103 rows x 1 columns]

# %%
character_df[character_df['Official English Name']=='Charlotte Katakuri']
# Out:
#     Official English Name  Debut      Affiliations      Occupations Status  \
# 235    Charlotte Katakuri  860.0  Charlotte Family  Sweet Commander  Alive
#
#         Birthday  Devil Fruit  Observation Haki  Armament Haki  \
# 235  November 25            1                 1              1
#
#      Conquerers Haki      Origin   Age  Height Blood Type         Fruit Type  \
# 235                1  Grand Line  48.0   509.0         XF  Special Paramecia
#
#            Bounty
# 235  1.057000e+09

# %%
character_df.loc[character_df.iloc[:, character_df.columns.get_loc('Affiliations')].str.contains('Charlotte Family', na=False)]
# Out:
#      Official English Name  Debut                            Affiliations  \
# 194       Charlotte Akimeg  894.0  Charlotte Family (Charlotte Decuplets)
# 195       Charlotte Allmeg  894.0  Charlotte Family (Charlotte Decuplets)
# 196       Charlotte Amande  827.0                        Charlotte Family
# 197        Charlotte Anana  845.0                        Charlotte Family
# 198        Charlotte Angel  860.0                        Charlotte Family
# ...                    ...    ...                                     ...
# 276       Charlotte Wafers  845.0                        Charlotte Family
# 277         Charlotte Uiro  845.0                        Charlotte Family
# 278         Charlotte Yuen  894.0                        Charlotte Family
# 279     Charlotte Zuccotto  862.0                        Charlotte Family
# 1135                 Pound  831.0             Charlotte Family (Former) ‡
#
#          Occupations Status     Birthday  Devil Fruit  Observation Haki  \
# ...

# %%
character_df.loc[character_df.iloc[:, character_df.columns.get_loc('Affiliations')].str.contains('Rocks Pirates', na=False)]
# Out:
#      Official English Name   Debut            Affiliations      Occupations  \
# 69                 Barbell  1096.0  Rocks Pirates (former)           Pirate
# 152      Buckingham Stussy   802.0  Rocks Pirates (former)  Pirate (former)
# 475                 Ganzui   450.0  Rocks Pirates (former)   General Zombie
# 690                   John   450.0  Rocks Pirates (former)   General Zombie
# 822                    Kyo  1156.0  Rocks Pirates (former)           Pirate
# 885                 Marlon  1155.0           Rocks Pirates           Pirate
# 1063              Wang Zhi  1155.0  Rocks Pirates (former)      Pirate Guru
# 1194        Rocks D. Xebec   957.0           Rocks Pirates   Pirate Captain
#
#         Status  Birthday  Devil Fruit  Observation Haki  Armament Haki  \
# 69     Unknown       NaN            0                 0              0
# 152      Alive  April 12            0                 0              0
# ...

# %%
8_816_001_000.0

# %%
character_df.loc[character_df.iloc[:, character_df.columns.get_loc('Status')].isin(['Deceased', 'Destroyed'])]
# Out:
#      Official English Name   Debut  \
# 2                  Absalom   444.0
# 39      Kicking Claw Force   196.0
# 41            Aruyutayan V   292.0
# 44             Ashura Doji   920.0
# 45                    Asla  1153.0
# ...                    ...     ...
# 1481         Vinsmoke Sora   841.0
# 1499           Warrior God  1175.0
# 1538                  Zabo   241.0
# 1539                 Zayde   391.0
# 1546                  Zepo   850.0
#
#                                            Affiliations  \
# 2     Thriller Bark Pirates (Mysterious Four)  (former)
# 39                                     Arabasta Kingdom
# 41                                       Lvneel Kingdom
# 44                                    Mt. Atama Thieves
# 45                                  Elbaph Royal Family
# ...                                                 ...
# 1481                                    Vinsmoke Family
# 1499                                                NaN
# ...
